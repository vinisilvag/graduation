# %%
import numpy as np
import pandas as pd

import math

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.utils import shuffle

plt.rcParams['figure.figsize']  = (10, 6)
plt.rcParams['axes.labelsize']  = 10
plt.rcParams['axes.titlesize']  = 10
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['lines.linewidth'] = 2

plt.ion()
plt.style.use('seaborn-colorblind')

sns.set_theme(style="whitegrid")

# %%
df_tiktok = pd.read_csv('../data/tiktok_clean.csv')
df_not_pop = pd.read_csv('../data/nao_pop.csv')
df_not_pop_in_tiktok = pd.read_csv('../data/populares_mas_nao_no_tiktok.csv')

# %%
df_tiktok
# Out:
#                     track_id                         track_name  \
# 0     6kVuF2PYLuvl9T85XjNbaO            Lay It Down Gmix - Main
# 1     1RGIjMFMgJxkZHMDXVYzOJ             Bartender (feat. Akon)
# 2     1dIWPXMX4kRHj6Dt2DStUQ       Chosen (feat. Ty Dolla $ign)
# 3     4QVS8YCpK71R4FsxSMCjhP      Tie Me Down (with Elley Duhé)
# 4     7BoobGhD4x5K96Me0hqC8Q                      Build a Bitch
# ...                      ...                                ...
# 4024  1lNHWPDvKEbamKezpLq7HW                no song without you
# 4025  7gd01LMH2gBcoDngSt8sq9  Next To You (feat. Justin Bieber)
# 4026  5PYQUBXc7NYeI1obMKSJK0                  Never Really Over
# 4027  37f4ITSlgPX81ad2EvmVQr                         Fight Song
# 4028  60jpDubMmVyR5molJp2TCm      Ice Cream (with Selena Gomez)
#
#                    artist_id     artist_name                album_id  \
# 0     1Xfmvd48oOhEWkscWyEbh9           Lloyd  43C6GVlhXG4KfZuEbxty3r
# 1     3aQeKQSyrW4qWr35idm0cy          T-Pain  6CrSEKCF4TYrbSIitegb3h
# 2     4qXC0i02bSFstECuXP2ZpL           Blxst  7AwrgenNcTAJlJF3pKL0Qr
# 3     2ZRQcIgzPCVaT9XKhXZIzh         Gryffin  69t8rpgBN1ov5kCU6LDMuR
# 4     26cMerAxjx9GedFt0lMDjm    Bella Poarch  5YKqfiQdPYWJ0kZ5pttY5o
# ...                      ...             ...                     ...
# 4024  0Vw76uk7P8yVtTClWyOhac           HONNE  3DG5MS8iKYcJROCnb1DYDf
# 4025  7bXgB6jMjp9ATFy66eO08Z     Chris Brown  6df0qvkMXoyHGt9J8cujZb
# 4026  6jJ0s89eD6GaHleKKya26X      Katy Perry  3KjXg0MDej2pG9fv6I22lT
# 4027  3QLIkT4rD2FMusaqmkepbq  Rachel Platten  0mFDIOqypzHp6Xd0el1hoT
# 4028  41MozSoPIsD1dJM0CLPjZF       BLACKPINK  0J1uiXQshfRtz2R8lgUlQk
#
#       duration release_date  popularity  danceability  energy  ...  \
# 0       302186   2011-01-01          28         0.597   0.800  ...
# 1       238800   2007-06-05          75         0.832   0.391  ...
# 2       161684   2020-12-04          76         0.571   0.767  ...
# 3       218295   2018-08-03          72         0.548   0.839  ...
# 4       122772   2021-05-14          89         0.855   0.463  ...
# ...        ...          ...         ...           ...     ...  ...
# 4024    160346   2020-07-03          64         0.788   0.473  ...
# 4025    265813   2011-03-22          70         0.670   0.676  ...
# 4026    223523   2019-05-31          77         0.770   0.882  ...
# 4027    204013   2016-01-01          79         0.564   0.714  ...
# 4028    175813   2020-08-28          19         0.791   0.733  ...
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.3120        0.0461          0.000000    0.1800    0.565  155.932
# 1          0.0628        0.0564          0.000000    0.2240    0.436  104.961
# 2          0.2870        0.3360          0.000000    0.0809    0.605   93.421
# 3          0.0644        0.1350          0.000000    0.1020    0.314   98.932
# 4          0.0367        0.2170          0.000018    0.3470    0.866  102.931
# ...           ...           ...               ...       ...      ...      ...
# 4024       0.0328        0.4890          0.254000    0.1090    0.810  105.429
# 4025       0.0370        0.0201          0.000000    0.1100    0.349  114.974
# 4026       0.0602        0.1940          0.000000    0.3160    0.385   99.991
# 4027       0.1290        0.0549          0.000000    0.1550    0.330  175.924
# 4028       0.3500        0.0305          0.000169    0.0423    0.913  159.974
#
#                  playlist_id  \
# 0     6kVuF2PYLuvl9T85XjNbaO
# 1     1RGIjMFMgJxkZHMDXVYzOJ
# 2     1dIWPXMX4kRHj6Dt2DStUQ
# 3     4QVS8YCpK71R4FsxSMCjhP
# 4     7BoobGhD4x5K96Me0hqC8Q
# ...                      ...
# 4024  1uOzLrMZoqPIIctv9m48L0
# 4025  1uOzLrMZoqPIIctv9m48L0
# 4026  1uOzLrMZoqPIIctv9m48L0
# 4027  1uOzLrMZoqPIIctv9m48L0
# 4028  1uOzLrMZoqPIIctv9m48L0
#
#                                           playlist_name  duration_mins  \
# 0                                6kVuF2PYLuvl9T85XjNbaO       5.036433
# 1                                1RGIjMFMgJxkZHMDXVYzOJ       3.980000
# 2                                1dIWPXMX4kRHj6Dt2DStUQ       2.694733
# 3                                4QVS8YCpK71R4FsxSMCjhP       3.638250
# 4                                7BoobGhD4x5K96Me0hqC8Q       2.046200
# ...                                                 ...            ...
# 4024  TikTok Trending Philippines: It Really Hurts G...       2.672433
# 4025  TikTok Trending Philippines: It Really Hurts G...       4.430217
# 4026  TikTok Trending Philippines: It Really Hurts G...       3.725383
# 4027  TikTok Trending Philippines: It Really Hurts G...       3.400217
# 4028  TikTok Trending Philippines: It Really Hurts G...       2.930217
#
#      release_year
# 0            2011
# 1            2007
# 2            2020
# 3            2018
# 4            2021
# ...           ...
# 4024         2020
# 4025         2011
# 4026         2019
# 4027         2016
# 4028         2020
#
# [4029 rows x 23 columns]

# %%
df_not_pop
# Out:
#                     track_id  duration  popularity  danceability  energy  key  \
# 0     2P1mLMA0W0wpLPPlYIhBa9    209176          22         0.488   0.832    2
# 1     2Zh1LkF9VziQVUjzIFlyi9    367426          41         0.565   0.680    7
# 2     1390XaOMSPI8rJUyKiL18Y    268250           3         0.566   0.742    4
# 3     1bqerS49YfUgCimJQJPUsC    201504          27         0.598   0.680    9
# 4     5trdk633doJmre0SiVIZwV    292480          13         0.516   0.906    9
# ...                      ...       ...         ...           ...     ...  ...
# 2495  2hvkMwP8VNMyxTHnXJSDRL    204511          26         0.458   0.799    6
# 2496  5d8lDiG2BrvdiosoZYl5lD    257088          27         0.522   0.747    2
# 2497  3gAQXcQx8kkQdZfa5dK7br    193038           4         0.493   0.846    2
# 2498  4olsMaLbdIBrk2Iwq0s00V    327388          32         0.697   0.686   10
# 2499  1nn2UmCLigX0q28zI1ETdb    197538           3         0.602   0.880    4
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0       -2.332     0       0.0418      0.010700            0.3950    0.1120
# 1       -7.609     1       0.0269      0.004600            0.0936    0.0760
# 2       -5.875     0       0.0336      0.001610            0.2380    0.1070
# 3      -11.749     0       0.0507      0.413000            0.8940    0.1110
# 4       -7.155     1       0.0347      0.032400            0.5830    0.1320
# ...        ...   ...          ...           ...               ...       ...
# 2495    -7.587     1       0.0444      0.000636            0.0493    0.2520
# 2496    -9.554     1       0.0330      0.000022            0.8680    0.1390
# 2497    -5.953     1       0.0280      0.007160            0.8490    0.0955
# 2498    -9.602     1       0.0283      0.034400            0.7600    0.1130
# 2499    -5.509     0       0.0632      0.000250            0.7040    0.1200
#
#       valence    tempo  duration_mins  release_year
# 0       0.422  107.015       3.486267          2022
# 1       0.121  116.973       6.123767          1989
# 2       0.140  119.952       4.470833          2021
# 3       0.426  156.018       3.358400          2016
# 4       0.275  155.996       4.874667          2022
# ...       ...      ...            ...           ...
# 2495    0.354  139.926       3.408517          1995
# 2496    0.313  124.995       4.284800          2019
# 2497    0.447  134.966       3.217300          2022
# 2498    0.679  135.022       5.456467          2016
# 2499    0.428  129.998       3.292300          2021
#
# [2500 rows x 16 columns]

# %%
df_not_pop_in_tiktok
# Out:
#                    track_id  \
# 0    5u1n1kITHCxxp8twBcZxWy
# 1    09CtPGIpYB4BrO8qb1RGsF
# 2    4B0JvthVoAAuygILe3n4Bs
# 3    190jyVPHYjAqEaOGmMzdyk
# 4    5GYbkDveRD2I8M5ZJ14hWn
# ..                      ...
# 419  0T5iIrXA4p5GsubkhuBIKV
# 420  4gzsuuZypVbxs0Af1LSZyB
# 421  3AQ5NssLWxymYXieUxx0cZ
# 422  2mrCfuTOJgWC4RPx8RblQk
# 423  0GASGMsvFkhYOohdBnMdtx
#
#                                             track_name  \
# 0                       Holy (feat. Chance The Rapper)
# 1                                                Sorry
# 2                                    What Do You Mean?
# 3                                    Beauty And A Beat
# 4                                      Never Say Never
# ..                                                 ...
# 419                                  Until I Found You
# 420  Lo Siento BB:/ (with Bad Bunny & Julieta Venegas)
# 421                                             Arcade
# 422                                             Pierre
# 423                       Somebody That I Used To Know
#
#                   artist_id      artist_name                album_id  \
# 0    1uNFoZAHBGtllmzznpCI3s    Justin Bieber  4hR7jjsPvRwwcHx8ntJSQS
# 1    1uNFoZAHBGtllmzznpCI3s    Justin Bieber  6Fr2rQkZ383FcMqFyT7yPr
# 2    1uNFoZAHBGtllmzznpCI3s    Justin Bieber  6Fr2rQkZ383FcMqFyT7yPr
# 3    1uNFoZAHBGtllmzznpCI3s    Justin Bieber  70f70xLCpH7wHaVvB2oZT9
# 4    1uNFoZAHBGtllmzznpCI3s    Justin Bieber  0wZJCeyfJ0LVrrtH4CwQYw
# ..                      ...              ...                     ...
# 419  5XKFrudbV4IiuE5WuTPRmT  Stephen Sanchez  18CtLoAMTr7F8ngtuM6D8i
# 420  0GM7qgcRCORpGnfcN2tCiB            Tainy  4589OIFRZp41qbsp7TWFCx
# 421  3klZnJvYGIbWritVwQD434  Duncan Laurence  3204xz1w0KPgaXDOuQ5kMu
# 422  2MuFzH1J5I6gGFYo2qhZmX       Ryn Weaver  3204xz1w0KPgaXDOuQ5kMu
# 423  2AsusXITU8P25dlRNhcAbG            Gotye  3204xz1w0KPgaXDOuQ5kMu
#
#      duration release_date  popularity  danceability  energy  ...  \
# 0      212093   2020-09-18          73         0.673   0.704  ...
# 1      200786   2015-11-13          82         0.654   0.760  ...
# 2      205680   2015-11-13          78         0.845   0.567  ...
# 3      227986   2012-06-15          74         0.602   0.843  ...
# 4      227853   2011-01-01          72         0.739   0.807  ...
# ..        ...          ...         ...           ...     ...  ...
# 419    177720   2021-09-01          89         0.539   0.508  ...
# 420    207301   2021-10-05          86         0.639   0.703  ...
# 421    185146   2021-04-05           3         0.447   0.348  ...
# 422    202746   2021-04-05           1         0.607   0.827  ...
# 423    245755   2021-04-05           4         0.865   0.511  ...
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0         0.3600      0.196000          0.000000    0.0898    0.372   86.919
# 1         0.0450      0.079700          0.000000    0.2990    0.410   99.945
# 2         0.0956      0.590000          0.001420    0.0811    0.793  125.020
# 3         0.0593      0.000688          0.000053    0.0682    0.526  128.003
# 4         0.0652      0.018100          0.000000    0.2950    0.632   97.048
# ..           ...           ...               ...       ...      ...      ...
# 419       0.0288      0.727000          0.000000    0.1740    0.227  101.358
# 420       0.0794      0.088900          0.000002    0.0865    0.138  169.888
# 421       0.0433      0.816000          0.001580    0.1400    0.235   72.180
# 422       0.0483      0.289000          0.000003    0.7180    0.552  100.066
# 423       0.0362      0.544000          0.000094    0.1020    0.774  129.059
#
#      duration_mins             playlist_id  playlist_name  release_year
# 0         3.534883  56uBMvAujYa1ZLSqkYk6hg          final          2020
# 1         3.346433  56uBMvAujYa1ZLSqkYk6hg          final          2015
# 2         3.428000  56uBMvAujYa1ZLSqkYk6hg          final          2015
# 3         3.799767  56uBMvAujYa1ZLSqkYk6hg          final          2012
# 4         3.797550  56uBMvAujYa1ZLSqkYk6hg          final          2011
# ..             ...                     ...            ...           ...
# 419       2.962000  56uBMvAujYa1ZLSqkYk6hg          final          2021
# 420       3.455017  56uBMvAujYa1ZLSqkYk6hg          final          2021
# 421       3.085767  56uBMvAujYa1ZLSqkYk6hg          final          2021
# 422       3.379100  56uBMvAujYa1ZLSqkYk6hg          final          2021
# 423       4.095917  56uBMvAujYa1ZLSqkYk6hg          final          2021
#
# [424 rows x 23 columns]

# %%
col_tiktok = df_tiktok.columns
col_not_pop = df_not_pop.columns
col_not_pop_in_tiktok = df_not_pop_in_tiktok.columns

intersect = [item for item in col_tiktok if item in col_not_pop]

df_tiktok_filtered = df_tiktok[intersect].copy()
df_not_pop_filtered = df_not_pop[intersect].copy()
df_not_pop_in_tiktok = df_not_pop_in_tiktok[intersect].copy()

# %%
df_tiktok_filtered['base'] = 0
df_not_pop_filtered['base'] = 1
df_not_pop_in_tiktok['base'] = 2

df_tiktok_filtered = df_tiktok_filtered.sample(n=len(df_not_pop_in_tiktok))
df_not_pop_filtered = df_not_pop_filtered.sample(n=len(df_not_pop_in_tiktok))

# %%
frames = [df_tiktok_filtered, df_not_pop_filtered, df_not_pop_in_tiktok]
df = pd.concat(frames)

# %%
df = shuffle(df)

# %%
df
# Out:
#                     track_id  duration  popularity  danceability  energy  key  \
# 2019  36XJWjuNKBax6KqdzpH7Wb    275840           0         0.603   0.872    2
# 1366  6iRb9aaEuKAKNitJJIZ5ke    345140          31         0.564   0.897    5
# 2037  4xigPf2sigSPmuFH3qCelB    213706          76         0.603   0.615   11
# 47    6f49kbOuQSOsStBpyGvQfA    223773          68         0.449   0.920   11
# 1039  2KMLGJ1mPfRE4GNdL92rl3    190306          61         0.469   0.425    5
# ...                      ...       ...         ...           ...     ...  ...
# 140   0PT7nlpo11hYYyfnBgtilT    142212          64         0.779   0.472   11
# 247   5cCAZS9VhLGEDV4NCfieeg    210266          66         0.696   0.546    5
# 1231  5Uf1vCvPN3RLVIbDUMoCEp    147380          16         0.845   0.673    5
# 68    1u8c2t2Cy7UBoG4ArRcF5g    231826          85         0.760   0.703    5
# 329   6i9ToXS6CAfjpp8veBklg1    190434          56         0.776   0.500   11
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 2019    -7.358     1       0.0577       0.00121          0.000005    0.7540
# 1366    -6.514     1       0.0310       0.00293          0.060500    0.0666
# 2037    -4.931     0       0.1650       0.07990          0.000067    0.1170
# 47      -4.982     1       0.0737       0.00210          0.016700    0.3340
# 1039    -9.474     0       0.0304       0.92000          0.000064    0.1440
# ...        ...   ...          ...           ...               ...       ...
# 140     -7.116     1       0.2180       0.05770          0.000000    0.1140
# 247     -6.550     1       0.0414       0.00379          0.000004    0.3320
# 1231    -5.932     1       0.2420       0.01500          0.000000    0.0621
# 68      -5.412     1       0.0540       0.10300          0.000000    0.0913
# 329     -4.788     1       0.0979       0.05370          0.000000    0.3440
#
#       valence    tempo  duration_mins  release_year  base
# 2019   0.6860  132.820       4.597333          1981     1
# 1366   0.2500  119.004       5.752333          2020     1
# 2037   0.5610  158.657       3.561767          2019     0
# 47     0.0772  122.984       3.729550          2015     2
# 1039   0.4810  103.128       3.171767          2020     0
# ...       ...      ...            ...           ...   ...
# 140    0.4120  135.051       2.370200          2015     0
# 247    0.7870  130.002       3.504433          2011     2
# 1231   0.4700   99.061       2.456333          2020     0
# 68     0.5700   95.997       3.863767          2014     2
# 329    0.4910   92.027       3.173900          2019     2
#
# [1272 rows x 17 columns]

# %%
pca = PCA(n_components = 2)
kmeans = KMeans(n_clusters = 3, init = 'random', n_init = 10, max_iter = 1000)

# %%
#PCA

features = ['duration', 'popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
            'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_mins', 'release_year']

samples = df.loc[:, features].values
labels = df['base'].values

samples = StandardScaler().fit_transform(samples)
df_pca = pca.fit_transform(samples)

data = []

for i, item in enumerate(df_pca):
    data.append([item[0], item[1], labels[i]])
    
data = np.array(data)

# %%
print('Variância explicada por cada componente:', pca.explained_variance_ratio_)
print('Total da variância explicada:', pca.explained_variance_ratio_.cumsum()[1])
# Out:
# Variância explicada por cada componente: [0.20731291 0.13136105]
# Total da variância explicada: 0.3386739655310158

# %%
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap="Accent", alpha=0.7)
plt.title("Scatter plot dos dados após o PCA")
plt.xlabel('Primeira componente')
plt.ylabel('Segunda componente')
plt.show()

# %%
pred = kmeans.fit_predict(data)

plt.scatter(data[:, 0], data[:, 1], c=pred, cmap="Accent")
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 70, c = 'red')
plt.title("Clusterização do dataset")
plt.xlabel('Primeira componente')
plt.ylabel('Segunda componente')
plt.show()

# %%
np.unique(pred)
# Out:
# array([0, 1, 2], dtype=int32)

# %%
unique, counts = np.unique(labels, return_counts=True)
original = dict(zip(unique, counts))

compare = {'original': original,
           'cluster': { 0: { 0: 0, 1: 0, 2: 0 }, 1: { 0: 0, 1: 0, 2: 0 }, 2: { 0: 0, 1: 0, 2: 0 } }
          }

for i, item in enumerate(data):
    compare['cluster'][pred[i]][data[i][2]] += 1
    
print(compare)
# Out:
# {'original': {0: 424, 1: 424, 2: 424}, 'cluster': {0: {0: 99, 1: 16, 2: 119}, 1: {0: 25, 1: 385, 2: 48}, 2: {0: 300, 1: 23, 2: 257}}}

# %%
print("Label 0: músicas presentes no dataset original")
print("Label 1: músicas não populares e não presentes no dataset original")
print("Label 2: músicas populares mas não presentes no dataset original\n")

for label in compare['cluster']:
    zero = compare['cluster'][label][0]
    one = compare['cluster'][label][1]
    two = compare['cluster'][label][2]
    
    print(f"A label {label} é composta por: {zero} da label 0, {one} da label 1 e {two} da label 2.")
# Out:
# Label 0: músicas presentes no dataset original
# Label 1: músicas não populares e não presentes no dataset original
# Label 2: músicas populares mas não presentes no dataset original
#
# A label 0 é composta por: 99 da label 0, 16 da label 1 e 119 da label 2.
# A label 1 é composta por: 25 da label 0, 385 da label 1 e 48 da label 2.
# A label 2 é composta por: 300 da label 0, 23 da label 1 e 257 da label 2.
